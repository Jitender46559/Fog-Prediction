# %%
import pandas as pd

train = pd.read_csv('C:/Users/Jitender kumar/Desktop/IMD/0117.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2131 entries, 0 to 2130
# Data columns (total 35 columns):
# DATE            2129 non-null object
# TIME            2129 non-null object
# MET             2129 non-null object
# DT              2129 non-null object
# WD_WS           2129 non-null object
# F               2129 non-null object
# G               2129 non-null object
# H               2129 non-null object
# I               2129 non-null object
# J               2129 non-null object
# VISIBILITY      2129 non-null object
# L               2023 non-null object
# M               2023 non-null object
# N               2023 non-null object
# O               2023 non-null object
# P               2023 non-null object
# Q               2023 non-null object
# R               2023 non-null object
# WEATHER         2129 non-null object
# LOWEST_CLOUD    368 non-null object
# LOW_CLOUD       1652 non-null object
# MID_CLOUD       633 non-null object
# HIGH_CLOUD      0 non-null float64
# X               2129 non-null float64
# Y               2129 non-null float64
# Z               2129 non-null float64
# AA              2129 non-null float64
# CURRENT_TEMP    2129 non-null float64
# DEW_POINT       2129 non-null object
# AD              0 non-null float64
# AE              2128 non-null object
# AF              0 non-null float64
# AG              2129 non-null object
# AH              2123 non-null object
# AI              2129 non-null object
# dtypes: float64(8), object(27)
# memory usage: 582.8+ KB

# %%
train.head(20)
# Out:
#           DATE   TIME  MET     DT   WD_WS       F       G       H       I  \
# 0   03-01-2017    631  MET  30630  310/04  280/04  330/04  340/03  280/03
# 1   04-01-2017    701  MET  30700  280/05  280/07  270/05  300/04  310/04
# 2   05-01-2017    731  MET  30730  290/04  310/05  280/04  320/02  280/05
# 3   06-01-2017    731  MET  30730  290/04  310/05  280/04  320/02  280/05
# 4   07-01-2017    801  MET  30800  290/04  300/05  280/04  320/04  280/05
# 5   08-01-2017    801  MET  30800  290/04  300/05  280/04  320/04  280/05
# 6   09-01-2017    801  MET  30800  290/04  300/05  280/04  320/04  280/05
# 7   10-01-2017  08:30  MET  30830  290/06  310/07  300/04  270/05  280/07
# 8   11-01-2017  08:30  MET  30830  290/06  310/07  300/04  270/05  280/07
# 9   12-01-2017  09:00  MET  30900  290/05  300/06  300/04  280/05  280/07
# 10  13-01-2017  08:30  MET  30830  290/06  310/07  300/04  270/05  280/07
# 11  14-01-2017  08:30  MET  30830  290/06  310/07  300/04  270/05  280/07
# 12  15-01-2017  09:30  MET  30930  310/05  310/06  300/04  270/05  280/07
# 13  16-01-2017  09:30  MET  30930  310/05  310/06  300/04  270/05  280/07
# 14  17-01-2017  10:00  MET  31030  310/05  310/06  290/05  300/07  310/06
# 15  18-01-2017  10:00  MET  31000  310/05  310/06  290/05  300/07  310/06
# 16  19-01-2017  10:00  MET  31000  310/05  310/06  290/05  300/07  310/06
# 17  20-01-2017  10:30  MET  31030  310/05  310/06  290/05  300/07  300/04
# 18  21-01-2017  10:30  MET  31030  310/05  310/06  280/06  280/05  300/04
# 19  22-01-2017  10:32  MET  31030  310/05  310/06  280/05  300/04  310/06
#
#          J        ...             Z      AA CURRENT_TEMP DEW_POINT  AD  \
# 0   280/04        ...         993.0  2932.0         16.0        13 NaN
# 1   270/03        ...         992.0  2928.0         18.0        13 NaN
# 2   260/05        ...         991.0  2928.0         20.0        13 NaN
# 3   260/05        ...         991.0  2928.0         20.0        13 NaN
# 4   250/04        ...         991.0  2927.0         21.0        13 NaN
# 5   250/04        ...         991.0  2927.0         21.0        13 NaN
# 6   250/04        ...         991.0  2927.0         21.0        13 NaN
# 7   270/07        ...         990.0  2926.0         21.0        13 NaN
# 8   270/07        ...         990.0  2926.0         21.0        13 NaN
# 9   270/07        ...         990.0  2926.0         22.0        13 NaN
# 10  270/07        ...         990.0  2926.0         21.0        13 NaN
# 11  270/07        ...         990.0  2926.0         21.0        13 NaN
# 12  270/07        ...         990.0  2926.0         22.0        13 NaN
# 13  270/07        ...         990.0  2926.0         22.0        13 NaN
# 14  270/06        ...         990.0  2924.0         22.0        12 NaN
# 15  270/06        ...         990.0  2924.0         22.0        12 NaN
# 16  270/06        ...         990.0  2924.0         22.0        12 NaN
# 17  270/06        ...         990.0  2924.0         22.0        12 NaN
# 18  270/04        ...         990.0  2924.0         22.0        12 NaN
# 19  270/06        ...         990.0  2924.0         22.0        12 NaN
#
#                        AE  AF   AG AH                AI
# 0                   NOSIG NaN  KSD  D  03-01-2017 07:46
# 1                   NOSIG NaN  KSD  E  03-01-2017 08:08
# 2                   NOSIG NaN  KSD  F  03-01-2017 08:42
# 3                   NOSIG NaN  KSD  F  03-01-2017 08:43
# 4   BECMG VIS 1500M IN FU NaN  KSD  G  03-01-2017 09:08
# 5   BECMG VIS 1500M IN FU NaN  KSD  G  03-01-2017 09:36
# 6   BECMG VIS 1500M IN FU NaN  KSD  G  03-01-2017 09:38
# 7   BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 09:41
# 8   BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 09:41
# 9                   NOSIG NaN  KSD  I  03-01-2017 10:15
# 10  BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 10:39
# 11  BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 10:46
# 12  BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 11:05
# 13  BECMG VIS 1500M IN FU NaN  KSD  H  03-01-2017 11:05
# 14                 NOSIG= NaN   SA  J  03-01-2017 11:08
# 15                 NOSIG= NaN   SA  J  03-01-2017 11:10
# 16                 NOSIG= NaN   SA  J  03-01-2017 11:25
# 17                 NOSIG= NaN   SA  K  03-01-2017 11:37
# 18                 NOSIG= NaN   SA  K  03-01-2017 11:38
# 19                 NOSIG= NaN   SA  K  03-01-2017 11:40
#
# [20 rows x 35 columns]

# %%
train.isnull().sum()
# Out:
# DATE               2
# TIME               2
# MET                2
# DT                 2
# WD_WS              2
# F                  2
# G                  2
# H                  2
# I                  2
# J                  2
# VISIBILITY         2
# L                108
# M                108
# N                108
# O                108
# P                108
# Q                108
# R                108
# WEATHER            2
# LOWEST_CLOUD    1763
# LOW_CLOUD        479
# MID_CLOUD       1498
# HIGH_CLOUD      2131
# X                  2
# Y                  2
# Z                  2
# AA                 2
# CURRENT_TEMP       2
# DEW_POINT          2
# AD              2131
# AE                 3
# AF              2131
# AG                 2
# AH                 8
# AI                 2
# dtype: int64

# %%
train.drop('F', axis=1, inplace=True)
train.drop('G', axis=1, inplace=True)
train.drop('H', axis=1, inplace=True)
train.drop('I', axis=1, inplace=True)
train.drop('J', axis=1, inplace=True)
train.drop('L', axis=1, inplace=True)
train.drop('M', axis=1, inplace=True)
train.drop('N', axis=1, inplace=True)
train.drop('O', axis=1, inplace=True)
train.drop('P', axis=1, inplace=True)
train.drop('Q', axis=1, inplace=True)
train.drop('R', axis=1, inplace=True)
train.drop('X', axis=1, inplace=True)
train.drop('Y', axis=1, inplace=True)
train.drop('Z', axis=1, inplace=True)
train.drop('AA', axis=1, inplace=True)
train.drop('AD', axis=1, inplace=True)
train.drop('AE', axis=1, inplace=True)
train.drop('AF', axis=1, inplace=True)
train.drop('AG', axis=1, inplace=True)
train.drop('AH', axis=1, inplace=True)
train.drop('AI', axis=1, inplace=True)
train.drop('HIGH_CLOUD', axis=1, inplace=True)
train.drop('MET', axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2131 entries, 0 to 2130
# Data columns (total 12 columns):
# DATE            2129 non-null object
# TIME            2129 non-null object
# MET             2129 non-null object
# DT              2129 non-null object
# WD_WS           2129 non-null object
# VISIBILITY      2129 non-null object
# WEATHER         2129 non-null object
# LOWEST_CLOUD    368 non-null object
# LOW_CLOUD       1652 non-null object
# MID_CLOUD       633 non-null object
# CURRENT_TEMP    2129 non-null float64
# DEW_POINT       2129 non-null object
# dtypes: float64(1), object(11)
# memory usage: 199.9+ KB

# %%
train.isnull().sum()
# Out:
# DATE               2
# TIME               2
# MET                2
# DT                 2
# WD_WS              2
# VISIBILITY         2
# WEATHER            2
# LOWEST_CLOUD    1763
# LOW_CLOUD        479
# MID_CLOUD       1498
# CURRENT_TEMP       2
# DEW_POINT          2
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
sb.set()

# %%
import missingno as ms

ms.matrix(train)

# %%
train['LOWEST_CLOUD'].fillna(0, inplace=True)
train['LOW_CLOUD'].fillna(0, inplace=True)
train['MID_CLOUD'].fillna(0, inplace=True)

# %%
train.isnull().sum()
# Out:
# DATE            2
# TIME            2
# MET             2
# DT              2
# WD_WS           2
# VISIBILITY      2
# WEATHER         2
# LOWEST_CLOUD    0
# LOW_CLOUD       0
# MID_CLOUD       0
# CURRENT_TEMP    2
# DEW_POINT       2
# dtype: int64

# %%
ms.matrix(train)

# %%
train.head()
# Out:
#          DATE TIME  MET     DT   WD_WS VISIBILITY WEATHER LOWEST_CLOUD  \
# 0  03-01-2017  631  MET  30630  310/04       1000      BR            0
# 1  04-01-2017  701  MET  30700  280/05       1000      FU            0
# 2  05-01-2017  731  MET  30730  290/04       1100      FU            0
# 3  06-01-2017  731  MET  30730  290/04       1100      FU            0
# 4  07-01-2017  801  MET  30800  290/04       1200      FU            0
#
#   LOW_CLOUD MID_CLOUD  CURRENT_TEMP DEW_POINT
# 0       NSC         0          16.0        13
# 1       NSC         0          18.0        13
# 2       NSC         0          20.0        13
# 3       NSC         0          20.0        13
# 4       NSC         0          21.0        13
